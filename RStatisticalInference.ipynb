# %% [markdown]
# <a href="https://colab.research.google.com/github/andrevsl/RStatisticalInference/blob/main/RStatisticalInference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)

# Use stdout as per normal...
print("Hello, world!")

# Use plots...
plot(cars)

# Even ggplot!
qplot(wt, mpg, data = mtcars, colour = factor(cyl))
# Out:
# [1] "Hello, world!"
# plot without title
# plot without title

# %%
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected string constant
# 1: !echo "# RStatisticalInference"
#           ^
# Traceback:

# %%
!touch README.md
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected symbol
# 1: !touch README.md
#            ^
# Traceback:

# %%
git init
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:5: unexpected symbol
# 1:
# 2: git init
#        ^
# Traceback:
